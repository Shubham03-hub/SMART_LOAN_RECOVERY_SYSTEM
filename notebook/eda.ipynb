# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   loan_id            5000 non-null   int64
#  1   age                5000 non-null   int64
#  2   income             5000 non-null   int64
#  3   employment_status  5000 non-null   object
#  4   loan_amount        5000 non-null   int64
#  5   interest_rate      5000 non-null   float64
#  6   loan_term          5000 non-null   int64
#  7   credit_score       5000 non-null   int64
#  8   past_due_payments  5000 non-null   int64
#  9   on_time_payments   5000 non-null   int64
#  10  collateral         3374 non-null   object
#  11  loan_type          5000 non-null   object
#  12  default            5000 non-null   int64
# dtypes: float64(1), int64(9), object(3)
# memory usage: 507.9+ KB

# %%
import pandas as pd

df = pd.read_csv("../data/LOAN_DATAS.csv")

df.head()
# Out:
#    loan_id  age  income employment_status  loan_amount  interest_rate  \
# 0        1   54   38828          Employed         6509           5.48
# 1        2   48   27806        Unemployed        49773          15.47
# 2        3   21  144288        Unemployed        27976           9.49
# 3        4   23  128709          Employed        33284           8.18
# 4        5   36  116646        Unemployed        32022          14.91
#
#    loan_term  credit_score  past_due_payments  on_time_payments collateral  \
# 0         36           705                  5                21    Vehicle
# 1         48           577                  3                19   Property
# 2         24           587                  4                23   Property
# 3         12           511                  3                48        NaN
# 4         12           740                  7                12        NaN
#
#   loan_type  default
# 0      Auto        0
# 1      Auto        1
# 2      Auto        0
# 3  Personal        1
# 4  Personal        1

# %%
df.isnull().sum()
# Out:
# loan_id                 0
# age                     0
# income                  0
# employment_status       0
# loan_amount             0
# interest_rate           0
# loan_term               0
# credit_score            0
# past_due_payments       0
# on_time_payments        0
# collateral           1626
# loan_type               0
# default                 0
# dtype: int64

# %%
df["default"].value_counts()
# Out:
# default
# 0    3247
# 1    1753
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#            loan_id          age         income  loan_amount  interest_rate  \
# count  5000.000000  5000.000000    5000.000000   5000.00000    5000.000000
# mean   2500.500000    42.527400   84441.080600  25715.36220      11.480324
# std    1443.520003    12.711552   37535.547124  14108.87642       3.745625
# min       1.000000    21.000000   20003.000000   1001.00000       5.000000
# 25%    1250.750000    32.000000   51519.500000  13608.50000       8.277500
# 50%    2500.500000    42.000000   83500.000000  25512.50000      11.480000
# 75%    3750.250000    54.000000  117149.750000  38120.25000      14.692500
# max    5000.000000    64.000000  149900.000000  49952.00000      18.000000
#
#          loan_term  credit_score  past_due_payments  on_time_payments  \
# count  5000.000000   5000.000000        5000.000000       5000.000000
# mean     36.098400    572.134800           4.505800         26.921800
# std      17.037194    157.148202           2.847383         13.132181
# min      12.000000    300.000000           0.000000          5.000000
# 25%      24.000000    437.000000           2.000000         16.000000
# 50%      36.000000    571.000000           4.000000         27.000000
# 75%      48.000000    707.000000           7.000000         38.000000
# max      60.000000    849.000000           9.000000         49.000000
#
#            default
# count  5000.000000
# mean      0.350600
# std       0.477206
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.isnull().sum()
# Out:
# loan_id                 0
# age                     0
# income                  0
# employment_status       0
# loan_amount             0
# interest_rate           0
# loan_term               0
# credit_score            0
# past_due_payments       0
# on_time_payments        0
# collateral           1626
# loan_type               0
# default                 0
# dtype: int64

# %%
df["default"].value_counts()
# Out:
# default
# 0    3247
# 1    1753
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x="default", data=df)
plt.title("Loan Default Distribution")
plt.show()

# %%
sns.boxplot(x="default", y="income", data=df)
plt.title("Income vs Loan Default")
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.heatmap(df.corr(numeric_only=True), annot=True)

plt.title("Feature Correlation Heatmap")

plt.show()
